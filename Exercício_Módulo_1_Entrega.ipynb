# %%
# Utilize o comando 'input' para receber ao menos 2 números de entrada do usuário:
horas_dia = 24
hora1_minutos = 60

acordar = input("Informe o seu horário de acordar: ")
dormir = input("Informe o seu horário de dormir: ")
print(acordar)
print(dormir)
# Out:
# Informe o seu horário de acordar: 6
# Informe o seu horário de dormir: 21
# 6
# 21

# %%
# Converta os valores recebidos pelo usuário para número inteiro (int) ou ponto flutuante (float):
horas_dia = 24
hora1_minutos = 60

acordar = float(input("Informe o seu horário de acordar: "))
dormir = float(input("Informe o seu horário de dormir: "))
print(acordar)
print(dormir)
# Out:
# Informe o seu horário de acordar: 6
# Informe o seu horário de dormir: 21
# 6.0
# 21.0

# %%
# Implemente ao menos 4 operações matemáticas em seu código:
horas_dia = 24
hora1_minutos = 60

acordar = float(input("Informe o seu horário de acordar: "))
dormir = float(input("Informe o seu horário de dormir: "))
soma = acordar + dormir
subtracao = acordar - dormir
multiplicacao = acordar * dormir
divisao = acordar / dormir
print(soma)
print(subtracao)
print(multiplicacao)
print(divisao)
# Out:
# Informe o seu horário de acordar: 6
# Informe o seu horário de dormir: 21
# 27.0
# -15.0
# 126.0
# 0.2857142857142857

# %%
# Adicione um laço de repetição ou uma condicional. Por exemplo: você pode permitir que o usuário escolha qual operação realizar ou criar um loop que permita ao usuário realizar várias operações consecutivas:
acordar = int(input("Informe o seu horário de acordar: "))
dormir = int(input("Informe o seu horário de dormir: "))

if acordar > dormir:
    print("O horário de acordar não pode ser maior que o horário de dormir.")
    acordar = int(input("Informe o seu horário de acordar: "))
    dormir = int(input("Informe o seu horário de dormir: "))
else:
    print("O horário de acordar é menor que o horário de dormir.")
# Out:
# Informe o seu horário de acordar: 6
# Informe o seu horário de dormir: 21
# O horário de acordar é menor que o horário de dormir.

# %%
# Utilize o comando 'print' para exibir o resultado da operação matemática.
